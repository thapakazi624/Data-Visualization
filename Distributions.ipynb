# %% [markdown]
# # Setup

# %%
import pandas as pd
pd.plotting.register_matplotlib_converters()
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %% [markdown]
# # Data

# %%
# iris data
iris_data = pd.read_csv('iris.csv', index_col='Id')

# %%
iris_data.head()
# Out:
#     Sepal Length (cm)  Sepal Width (cm)  Petal Length (cm)  Petal Width (cm)  \
# Id
# 1                 5.1               3.5                1.4               0.2
# 2                 4.9               3.0                1.4               0.2
# 3                 4.7               3.2                1.3               0.2
# 4                 4.6               3.1                1.5               0.2
# 5                 5.0               3.6                1.4               0.2
#
#         Species
# Id
# 1   Iris-setosa
# 2   Iris-setosa
# 3   Iris-setosa
# 4   Iris-setosa
# 5   Iris-setosa

# %% [markdown]
# # Histogram

# %%
# plotting histograms
sns.histplot(iris_data['Petal Length (cm)'])
# Out:
# <AxesSubplot:xlabel='Petal Length (cm)', ylabel='Count'>

# %% [markdown]
# # Density Plots

# %%
# Density plots done with Kernel Density Estimate (KDE)
sns.kdeplot(data=iris_data['Petal Length (cm)'], shade=True)
# Out:
# <AxesSubplot:xlabel='Petal Length (cm)', ylabel='Density'>

# %% [markdown]
# ## 2D KDE plots

# %%
# KDE plot can be done in 2d form
sns.jointplot(x=iris_data['Petal Length (cm)'], y=iris_data['Sepal Width (cm)'], kind='kde')

# %% [markdown]
# ## color coded histogram plots

# %%
# histograms for each species
sns.histplot(data=iris_data, x='Petal Length (cm)', hue='Species')

# title
plt.title('Histogram of Petal lengths by Species')
# Out:
# Text(0.5, 1.0, 'Histogram of Petal lengths by Species')

# %%
# color coded KDE for each species
sns.kdeplot(data=iris_data, x='Petal Length (cm)', hue='Species', shade=True)

# title
plt.title('Distribution of Petal lengths by Species')
# Out:
# Text(0.5, 1.0, 'Distribution of Petal lengths by Species')
